# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
# %config Inlinebackend.figure_format= 'retina'
sns.set_context("poster")
sns.set(rc={"figure.figsize": (12.,6.)})
sns.set_style("whitegrid")

# %%
dat1 = pd.read_csv('measurements.csv')
dat2 = pd.read_excel('measurements2.xlsx')
data1 = pd.DataFrame(dat1)
data2 = pd.DataFrame(dat2)
data2
# Out:
#      distance  consume  speed  temp_inside  temp_outside specials gas_type  \
# 0        28.0      5.0     26         21.5            12      NaN      E10
# 1        12.0      4.2     30         21.5            13      NaN      E10
# 2        11.2      5.5     38         21.5            15      NaN      E10
# 3        12.9      3.9     36         21.5            14      NaN      E10
# 4        18.5      4.5     46         21.5            15      NaN      E10
# ..        ...      ...    ...          ...           ...      ...      ...
# 383      16.0      3.7     39         24.5            18      NaN     SP98
# 384      16.1      4.3     38         25.0            31       AC     SP98
# 385      16.0      3.8     45         25.0            19      NaN     SP98
# 386      15.4      4.6     42         25.0            31       AC     SP98
# 387      14.7      5.0     25         25.0            30       AC     SP98
#
#      AC  rain  sun  refill liters refill gas
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   distance       388 non-null    object
#  1   consume        388 non-null    object
#  2   speed          388 non-null    int64
#  3   temp_inside    376 non-null    object
#  4   temp_outside   388 non-null    int64
#  5   specials       93 non-null     object
#  6   gas_type       388 non-null    object
#  7   AC             388 non-null    int64
#  8   rain           388 non-null    int64
#  9   sun            388 non-null    int64
#  10  refill liters  13 non-null     object
#  11  refill gas     13 non-null     object
# dtypes: int64(5), object(7)
# memory usage: 36.5+ KB

# %%
data2.specials.value_counts()
# Out:
# rain                  32
# sun                   27
# AC rain                9
# ac                     8
# AC                     6
# sun ac                 3
# snow                   3
# AC snow                1
# ac rain                1
# AC sun                 1
# AC Sun                 1
# half rain half sun     1
# Name: specials, dtype: int64

# %%
data2.specials.replace({'AC rain':'rain','AC sun': 'sun', 'sun ac': 'sun', 'AC Sun':'sun', 'ac':'AC', 'AC snow': 'snow','ac rain':'rain', 'half rain half sun': 'rain/sun'}, inplace = True)
data2.specials.fillna('Unknown', inplace = True)

# %%
data2.temp_inside.unique()
data2.temp_inside.fillna(0, inplace = True)
data2.temp_inside.astype('float64')
# Out:
# 0      21.5
# 1      21.5
# 2      21.5
# 3      21.5
# 4      21.5
#        ...
# 383    24.5
# 384    25.0
# 385    25.0
# 386    25.0
# 387    25.0
# Name: temp_inside, Length: 388, dtype: float64

# %%
data2.temp_outside.unique()
# Out:
# array([12, 13, 15, 14, 10, 11,  6,  4,  9,  0,  5,  3,  8,  1,  2,  7, -3,
#        17, 18, -5, 16, 19, 21, 20, 25, 23, 27, 24, 26, 22, 30, 31, 28])

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   distance       388 non-null    float64
#  1   consume        388 non-null    float64
#  2   speed          388 non-null    int64
#  3   temp_inside    388 non-null    float64
#  4   temp_outside   388 non-null    int64
#  5   specials       388 non-null    object
#  6   gas_type       388 non-null    object
#  7   AC             388 non-null    int64
#  8   rain           388 non-null    int64
#  9   sun            388 non-null    int64
#  10  refill liters  13 non-null     float64
#  11  refill gas     13 non-null     object
# dtypes: float64(4), int64(5), object(3)
# memory usage: 36.5+ KB

# %%
data2.specials.unique()
data2.drop(['specials'], axis = 1, inplace = True)

# %%
data2.head()
# Out:
#    distance  consume  speed  temp_inside  temp_outside gas_type  AC  rain  \
# 0      28.0      5.0     26         21.5            12      E10   0     0
# 1      12.0      4.2     30         21.5            13      E10   0     0
# 2      11.2      5.5     38         21.5            15      E10   0     0
# 3      12.9      3.9     36         21.5            14      E10   0     0
# 4      18.5      4.5     46         21.5            15      E10   0     0
#
#    sun  refill liters refill gas
# 0    0           45.0        E10
# 1    0            NaN        NaN
# 2    0            NaN        NaN
# 3    0            NaN        NaN
# 4    0            NaN        NaN

# %%
data2['refill gas'].value_counts()
# Out:
# SP98    8
# E10     5
# Name: refill gas, dtype: int64

# %%
data2.gas_type.value_counts()
# Out:
# SP98    228
# E10     160
# Name: gas_type, dtype: int64

# %%
data2.drop(['refill gas', 'refill liters'],axis = 1 ,inplace = True)

# %%
data2
# Out:
#      distance  consume  speed  temp_inside  temp_outside gas_type  AC  rain  \
# 0        28.0      5.0     26         21.5            12      E10   0     0
# 1        12.0      4.2     30         21.5            13      E10   0     0
# 2        11.2      5.5     38         21.5            15      E10   0     0
# 3        12.9      3.9     36         21.5            14      E10   0     0
# 4        18.5      4.5     46         21.5            15      E10   0     0
# ..        ...      ...    ...          ...           ...      ...  ..   ...
# 383      16.0      3.7     39         24.5            18     SP98   0     0
# 384      16.1      4.3     38         25.0            31     SP98   1     0
# 385      16.0      3.8     45         25.0            19     SP98   0     0
# 386      15.4      4.6     42         25.0            31     SP98   1     0
# 387      14.7      5.0     25         25.0            30     SP98   1     0
#
#      sun
# 0      0
# 1      0
# 2      0
# 3      0
# ...

# %%
corr = data2.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
corr
# Out:
#               distance   consume     speed  temp_inside  temp_outside  \
# distance      1.000000 -0.128967  0.562299     0.053597      0.088175
# consume      -0.128967  1.000000 -0.227866     0.027015     -0.320811
# speed         0.562299 -0.227866  1.000000     0.026817      0.015411
# temp_inside   0.053597  0.027015  0.026817     1.000000      0.077181
# temp_outside  0.088175 -0.320811  0.015411     0.077181      1.000000
# AC           -0.025738  0.096591 -0.035408     0.125307      0.167562
# rain         -0.019791  0.248118  0.009489     0.011845     -0.186315
# sun           0.081120 -0.170667  0.081618     0.060782      0.346903
#
#                     AC      rain       sun
# distance     -0.025738 -0.019791  0.081120
# consume       0.096591  0.248118 -0.170667
# speed        -0.035408  0.009489  0.081618
# temp_inside   0.125307  0.011845  0.060782
# temp_outside  0.167562 -0.186315  0.346903
# AC            1.000000  0.242915  0.088598
# ...

# %%
data2.describe()
# Out:
#          distance     consume       speed  temp_inside  temp_outside  \
# count  388.000000  388.000000  388.000000   388.000000    388.000000
# mean    19.652835    4.912371   41.927835    21.251289     11.358247
# std     22.667837    1.033172   13.598524     3.929366      6.991542
# min      1.300000    3.300000   14.000000     0.000000     -5.000000
# 25%     11.800000    4.300000   32.750000    21.500000      7.000000
# 50%     14.600000    4.700000   40.500000    22.000000     10.000000
# 75%     19.000000    5.300000   50.000000    22.500000     16.000000
# max    216.100000   12.200000   90.000000    25.500000     31.000000
#
#                AC        rain         sun
# count  388.000000  388.000000  388.000000
# mean     0.077320    0.123711    0.082474
# std      0.267443    0.329677    0.275441
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000
# ...

# %%
grupos = data2.groupby('gas_type')

# %%
data2.consume.unique()
# Out:
# array([ 5. ,  4.2,  5.5,  3.9,  4.5,  6.4,  4.4,  5.3,  5.6,  4.6,  5.9,
#         5.1,  4.7,  4.9,  5.7,  4.1,  5.8,  4.8,  4.3,  5.2,  7.4,  6.5,
#         4. ,  3.3,  9.9,  6.1,  6.2,  7.9, 12.2,  5.4,  3.6,  6.9,  8.7,
#         6.3,  6. , 10.8,  8.1,  7.1,  3.8,  9. ,  3.7, 11.5,  6.6])

# %%
binned = pd.cut(data2.consume, bins=10)
print(binned.value_counts())
# Out:
# (4.19, 5.08]      184
# (5.08, 5.97]       93
# (3.291, 4.19]      75
# (5.97, 6.86]       23
# (6.86, 7.75]        4
# (7.75, 8.64]        3
# (8.64, 9.53]        2
# (11.31, 12.2]       2
# (9.53, 10.42]       1
# (10.42, 11.31]      1
# Name: consume, dtype: int64

# %%
data2.head()
# Out:
#    distance  consume  speed  temp_inside  temp_outside gas_type  AC  rain  sun
# 0      28.0      5.0     26         21.5            12      E10   0     0    0
# 1      12.0      4.2     30         21.5            13      E10   0     0    0
# 2      11.2      5.5     38         21.5            15      E10   0     0    0
# 3      12.9      3.9     36         21.5            14      E10   0     0    0
# 4      18.5      4.5     46         21.5            15      E10   0     0    0

# %%
data2.consume = binned

# %%
data2
# Out:
#      distance        consume  speed  temp_inside  temp_outside gas_type  AC  \
# 0        28.0   (4.19, 5.08]     26         21.5            12      E10   0
# 1        12.0   (4.19, 5.08]     30         21.5            13      E10   0
# 2        11.2   (5.08, 5.97]     38         21.5            15      E10   0
# 3        12.9  (3.291, 4.19]     36         21.5            14      E10   0
# 4        18.5   (4.19, 5.08]     46         21.5            15      E10   0
# ..        ...            ...    ...          ...           ...      ...  ..
# 383      16.0  (3.291, 4.19]     39         24.5            18     SP98   0
# 384      16.1   (4.19, 5.08]     38         25.0            31     SP98   1
# 385      16.0  (3.291, 4.19]     45         25.0            19     SP98   0
# 386      15.4   (4.19, 5.08]     42         25.0            31     SP98   1
# 387      14.7   (4.19, 5.08]     25         25.0            30     SP98   1
#
#      rain  sun
# 0       0    0
# 1       0    0
# ...

# %%
guardar = data2.groupby(["gas_type", "consume"])["consume"].count().unstack().plot(kind="bar")
plt.show()
#Con este grafico veo que el consumo de los coche con el carburante SP98 consumen mas que los coches con E10.
